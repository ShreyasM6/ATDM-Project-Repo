# %% [markdown]
# Loading Libraries

# %%
import pandas as pd
import numpy as np
import os
import glob
import datetime as dt

# %% [markdown]
# Set the path where the CSV files are present

# %%
path = r'D:\St. Clair\Data Analytics for Business\DAB103- Analytic tools and Decision Making\Covid19'                     
all_files = glob.glob(os.path.join(path, "*.csv"))

# %% [markdown]
# Load multiple CSV files at once into a dataframe

# %%
df_from_each_file = (pd.read_csv(f) for f in all_files)
covid = pd.concat(df_from_each_file, ignore_index=True)

# %%
os.listdir(path)
# Out:
# ['01-01-2021.csv',
#  '01-02-2021.csv',
#  '01-03-2021.csv',
#  '01-04-2021.csv',
#  '01-05-2021.csv',
#  '01-06-2021.csv',
#  '01-07-2021.csv',
#  '01-08-2021.csv',
#  '01-09-2021.csv',
#  '01-10-2021.csv',
#  '01-11-2021.csv',
#  '01-12-2021.csv',
#  '01-13-2021.csv',
#  '01-14-2021.csv',
#  '01-15-2021.csv',
#  '01-16-2021.csv',
#  '01-17-2021.csv',
#  '01-18-2021.csv',
#  '01-19-2021.csv',
#  '01-20-2021.csv',
#  '01-21-2021.csv',
#  '01-22-2021.csv',
#  '01-23-2021.csv',
#  '01-24-2021.csv',
#  '01-25-2021.csv',
#  '01-26-2021.csv',
#  '01-27-2021.csv',
#  '01-28-2021.csv',
#  '01-29-2021.csv',
#  '01-30-2021.csv',
#  '01-31-2021.csv',
#  '02-01-2021.csv',
#  '02-02-2021.csv',
#  '02-03-2021.csv',
#  '02-04-2021.csv',
#  '02-05-2021.csv',
#  '02-06-2021.csv',
#  '02-07-2021.csv',
#  '02-08-2021.csv',
#  '02-09-2021.csv',
#  '02-10-2021.csv',
#  '02-11-2021.csv',
#  '02-12-2021.csv',
#  '02-13-2021.csv',
#  '02-14-2021.csv',
#  '02-15-2021.csv',
#  '02-16-2021.csv',
# ...

# %%
covid
# Out:
#       Province_State Country_Region          Last_Update      Lat     Long_  \
# 0            Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1             Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2     American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3            Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4           Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ...              ...            ...                  ...      ...       ...
# 3417        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 3418      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 3419   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 3420       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 3421         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
# ...

# %%
covid.isna().sum()
# Out:
# Province_State             0
# Country_Region             0
# Last_Update                0
# Lat                      118
# Long_                    118
# Confirmed                  0
# Deaths                     0
# Recovered                810
# Active                     0
# FIPS                       0
# Incident_Rate            118
# Total_Test_Results       118
# People_Hospitalized     3422
# Case_Fatality_Ratio       59
# UID                        0
# ISO3                       0
# Testing_Rate             118
# Hospitalization_Rate    3422
# dtype: int64

# %%
covid.dropna()
# Out:
# Empty DataFrame
# Columns: [Province_State, Country_Region, Last_Update, Lat, Long_, Confirmed, Deaths, Recovered, Active, FIPS, Incident_Rate, Total_Test_Results, People_Hospitalized, Case_Fatality_Ratio, UID, ISO3, Testing_Rate, Hospitalization_Rate]
# Index: []

# %%
covid
# Out:
#       Province_State Country_Region          Last_Update      Lat     Long_  \
# 0            Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1             Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2     American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3            Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4           Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ...              ...            ...                  ...      ...       ...
# 3417        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 3418      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 3419   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 3420       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 3421         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
# ...

# %%
covid.groupby(['Province_State']).sum()
# Out:
#                                 Lat       Long_  Confirmed   Deaths  \
# Province_State
# Alabama                   1906.7738  -5127.2357   26354921   441658
# Alaska                    3620.8713  -8991.8596    3176259    15285
# American Samoa            -841.9890 -10037.7880          0        0
# Arizona                   1990.0582  -6574.4408   42643681   757411
# Arkansas                  2063.2123  -5450.0129   16966012   279142
# California                2130.8558  -7061.2144  187987779  2357428
# Colorado                  2304.5282  -6213.3549   23054379   327316
# Connecticut               2454.2702  -4292.5686   14419682   411351
# Delaware                  2319.7915  -4454.9189    4452803    74975
# Diamond Princess             0.0000      0.0000       2891        0
# District of Columbia      2294.9466  -4544.5812    2118393    53504
# Florida                   1638.2117  -4819.5212   98997007  1552425
# Georgia                   1949.3954  -4934.9429   51823646   828555
# ...

# %%
covid.dropna(subset = ["Recovered"], inplace=True)

# %%
covid
# Out:
#       Province_State Country_Region          Last_Update      Lat     Long_  \
# 0            Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1             Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 3            Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4           Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# 6           Colorado             US  2021-01-02 05:30:44  39.0598 -105.3111
# ...              ...            ...                  ...      ...       ...
# 3415         Vermont             US  2021-03-01 05:30:39  44.0459  -72.7107
# 3416  Virgin Islands             US  2021-03-01 05:30:39  18.3358  -64.8963
# 3419   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 3420       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 3421         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
# ...

# %%
path = r'D:\St. Clair\Data Analytics for Business\DAB103- Analytic tools and Decision Making\Covid19' 
files= os.listdir(path)

# %%
df_total=pd.DataFrame()

# %%
for file in files :
    df_temp=pd.read_csv(path + "\\" + file)
    df_temp['filename']= file
    df_total=df_total.append(df_temp)

# %%
df_total
# Out:
#     Province_State Country_Region          Last_Update      Lat     Long_  \
# 0          Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1           Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2   American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3          Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4         Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ..             ...            ...                  ...      ...       ...
# 53        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 54      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 55   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 56       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 57         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# ...

# %%
df_total['Date']=df_total.filename[:-4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8ce330ed9a26> in <module>
# ----> 1 df_total['Date']=df_total.filename[:-4]
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3874
#    3875         if isinstance(value, Series):
# ...

# %%
df = pd.DataFrame([['  a  ', 10], ['  c  ', 5]])
df
# Out:
#        0   1
# 0    a    10
# 1    c     5

# %%
df.replace('^\s+', '', regex=True, inplace=True)
df
# Out:
#      0   1
# 0  a    10
# 1  c     5

# %%
df_total['Date'] = df_total['filename'].str.replace(r'.csv$', '')
# Out:
# <ipython-input-35-c6961f6fb9da>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_total['Date'] = df_total['filename'].str.replace(r'.csv$', '')

# %%
df_total
# Out:
#     Province_State Country_Region          Last_Update      Lat     Long_  \
# 0          Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1           Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2   American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3          Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4         Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ..             ...            ...                  ...      ...       ...
# 53        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 54      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 55   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 56       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 57         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# ...

# %%
del df_total["Date"]

# %%
df_total
# Out:
#     Province_State Country_Region          Last_Update      Lat     Long_  \
# 0          Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1           Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2   American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3          Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4         Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ..             ...            ...                  ...      ...       ...
# 53        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 54      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 55   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 56       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 57         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# ...

# %%
df_total['Date'] = df_total['filename'].str[:-4]

# %%
df_total
# Out:
#     Province_State Country_Region          Last_Update      Lat     Long_  \
# 0          Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1           Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2   American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3          Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4         Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ..             ...            ...                  ...      ...       ...
# 53        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 54      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 55   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 56       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 57         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# ...

# %%
df_total['datetime'] = pd.to_datetime(df_total['Date'], dayfirst=True)

# %%
df_total['Month'] = pd.DatetimeIndex(df_total['Date']).month

# %%
df_total
# Out:
#     Province_State Country_Region          Last_Update      Lat     Long_  \
# 0          Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1           Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2   American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3          Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4         Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ..             ...            ...                  ...      ...       ...
# 53        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 54      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 55   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 56       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 57         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered    Active  FIPS  ...  Total_Test_Results  \
# ...

# %%
df_total['Month_name'] = df_total['datetime'].dt.month_name(locale='English')

# %%
df_total
# Out:
#     Province_State Country_Region          Last_Update      Lat     Long_  \
# 0          Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1           Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2   American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3          Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4         Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ..             ...            ...                  ...      ...       ...
# 53        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 54      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 55   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 56       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 57         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered    Active  FIPS  ...  Case_Fatality_Ratio  \
# ...

# %%
df_total['Mon_Year'] = df_total['datetime'].dt.strftime('%b-%Y')

# %%
df_total
# Out:
#     Province_State Country_Region          Last_Update      Lat     Long_  \
# 0          Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1           Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2   American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3          Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4         Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ..             ...            ...                  ...      ...       ...
# 53        Virginia             US  2021-03-01 05:30:39  37.7693  -78.1700
# 54      Washington             US  2021-03-01 05:30:39  47.4009 -121.4905
# 55   West Virginia             US  2021-03-01 05:30:39  38.4912  -80.9545
# 56       Wisconsin             US  2021-03-01 05:30:39  44.2685  -89.6165
# 57         Wyoming             US  2021-03-01 05:30:39  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered    Active  FIPS  ...         UID  ISO3  \
# ...
